# %% [markdown]
# ## Standard Scalar

# %%
# Calculates mean & std dev of each col, mean=0, std dev=1

# %%
import pandas as pd

# %%
df = pd.read_csv('D:/Kaggle Datasets/IRIS.csv')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
X = df.drop('species', axis = 1)
Y = df['species']

# %%
X.shape
# Out:
# (150, 4)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
# transfroming non-scaled data into scaled data
scaler.fit_transform(X)
# fit - it means learns all the parameters like mean & std dev of each column of dataset
# transform - means start subtracting mean from each value in the column and then divide it with std dev
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
X_scaled = scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (150, 4)

# %%
X_scaled[:,2]  # all the rows and second index column
# Out:
# array([-1.3412724 , -1.3412724 , -1.39813811, -1.2844067 , -1.3412724 ,
#        -1.17067529, -1.3412724 , -1.2844067 , -1.3412724 , -1.2844067 ,
#        -1.2844067 , -1.227541  , -1.3412724 , -1.51186952, -1.45500381,
#        -1.2844067 , -1.39813811, -1.3412724 , -1.17067529, -1.2844067 ,
#        -1.17067529, -1.2844067 , -1.56873522, -1.17067529, -1.05694388,
#        -1.227541  , -1.227541  , -1.2844067 , -1.3412724 , -1.227541  ,
#        -1.227541  , -1.2844067 , -1.2844067 , -1.3412724 , -1.2844067 ,
#        -1.45500381, -1.39813811, -1.2844067 , -1.39813811, -1.2844067 ,
#        -1.39813811, -1.39813811, -1.39813811, -1.227541  , -1.05694388,
#        -1.3412724 , -1.227541  , -1.3412724 , -1.2844067 , -1.3412724 ,
#         0.53529583,  0.42156442,  0.64902723,  0.1372359 ,  0.47843012,
#         0.42156442,  0.53529583, -0.26082403,  0.47843012,  0.08037019,
#        -0.14709262,  0.25096731,  0.1372359 ,  0.53529583, -0.09022692,
# ...

# %%
X_scaled[:,2].mean()  # approx. 0
# Out:
# 3.315866100213801e-16

# %%
X_scaled[:,2].std()  # approx. 1
# Out:
# 0.9999999999999998
